# %%
from PIL import Image,ImageOps
import imagehash
import matplotlib.pyplot as plt

# %%
img1=Image.open('images/Landscape_2.jpeg')
img2=Image.open('images/Landscape_3.jpeg')
plt.imshow(img1)
# Out:
# (<matplotlib.image.AxesImage at 0x13d89812fd0>,
#  <matplotlib.image.AxesImage at 0x13d897dda58>)

# %%
plt.imshow(img2 )

# %%
img1=ImageOps.exif_transpose(img1)
img2=ImageOps.exif_transpose(img2)

# %%
def get_concat_h(im1, im2):
    dst = Image.new('RGB', (im1.width + im2.width, im1.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (im1.width, 0))
    return dst

def get_concat_v(im1, im2):
    dst = Image.new('RGB', (im1.width, im1.height + im2.height))
    dst.paste(im1, (0, 0))
    dst.paste(im2, (0, im1.height))
    return dst

get_concat_h(img1, img2).save('./newImg.jpg')

# %%
con_img=Image.open('newImg.jpg')
hash=imagehash.average_hash(con_img)
print(hash)
plt.imshow(con_img )
# Out:
# eeeecc0080002222
