# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
arr = (np.random.randn(5,5)>0)*1
np.where(arr==0,np.nan, arr)
# Out:
# array([[ 1., nan,  1., nan,  1.],
#        [nan, nan,  1.,  1.,  1.],
#        [nan, nan, nan, nan,  1.],
#        [ 1., nan,  1.,  1.,  1.],
#        [nan,  1.,  1., nan,  1.]])

# %%
img = cv2.imread('1.jpg')
img = np.where(np.all())
cv2.imshow('n',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
np.all([[False,True],[True,True]], axis=1)
# Out:
# array([False,  True])

# %%
np.all([3, 4, 5])
# Out:
# True

# %%
np.all([[True, True], [False, True]], where=[[False], [True]])
# Out:
# False
